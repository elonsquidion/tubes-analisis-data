# %% [markdown]
# <a href="https://colab.research.google.com/github/elonsquidion/tubes-analisis-data/blob/main/Data_Analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TUGAS DATA ANALISIS PENGENALAN KOMPUTASI KU-1103 (SOTAU)
#
# <h3 style="text-align:center">Kelompok 13</h3>
#
# | Nama | NIM |
# | --- | --- |
# | Muhammad Fikri | 1301194182 |
# | Muhammad Fikri | 1301194182 |
# | Muhammad Fikri | 1301194182 |
# | Muhammad Fikri | 1301194182 |
# | Muhammad Fikri | 1301194182 |
# | Jihan | 1301194182 |
#
# Sebuah pesan untuk mengetes sesuatu

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_funding = pd.read_csv('https://raw.githubusercontent.com/elonsquidion/tubes-analisis-data/main/tech_fundings.csv')
data_funding
# Out:
#       index         Company                      Website          Region  \
# 0         1        Internxt        https://internxt.com/           Spain
# 1         2        Dockflow         https://dockflow.com         Belgium
# 2         3       api.video            https://api.video          France
# 3         4         Buck.ai             https://buck.ai/   United States
# 4         5       Prodsight     https://www.prodsight.ai  United Kingdom
# ...     ...             ...                          ...             ...
# 3570   3571         Headout      https://www.headout.com   United States
# 3571   3572            OLIO          https://olioex.com/  United Kingdom
# 3572   3573  Trees for Life  https://treesforlife.org.uk  United Kingdom
# 3573   3574     Britishvolt     https://britishvolt.com/  United Kingdom
# 3574   3575         Greenly   https://www.greenly.earth/          France
#
#                      Vertical Funding Amount (USD) Funding Stage Funding Date
# ...

# %%
data_merger = pd.read_csv('https://raw.githubusercontent.com/elonsquidion/tubes-analisis-data/main/acquisitions_update_2021.csv', on_bad_lines='skip')
data_merger
# Out:
#         ID Parent Company Acquisition Year Acquisition Month  \
# 0        1          Apple             1988               Mar
# 1        2          Apple             1988               Jun
# 2        3          Apple             1988               Jun
# 3        4          Apple             1988               Jul
# 4        5          Apple             1989               Jan
# ...    ...            ...              ...               ...
# 1450  1451         Citrix             2015               Apr
# 1451  1452         Citrix             2016               Sep
# 1452  1453         Citrix             2017               Jan
# 1453  1454         Citrix             2018               Feb
# 1454  1455         Citrix             2021               Mar
#
#            Acquired Company                                      Business  \
# 0       Network Innovations                                      Software
# 1     Orion Network Systems                             Computer Software
# ...
